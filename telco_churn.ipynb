# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://shvmpz:Pioneer.254@localhost:3306/telco_churn')

# %%
tables = pd.read_sql_query("SHOW TABLES", engine)
tables.head()
# Out:
#   Tables_in_telco_churn
# 0         billing_table
# 1        customer_table
# 2        security_table
# 3         service_table
# 4       streaming_table

# %%
customer_data = pd.read_sql_query("SELECT * FROM customer_table", engine)
billing_data = pd.read_sql_query("SELECT * FROM billing_table", engine)
service_data = pd.read_sql_query("SELECT * FROM service_table", engine)
streaming_data = pd.read_sql_query("SELECT * FROM streaming_table", engine)
security_data = pd.read_sql_query("SELECT * FROM security_table", engine)
query = """SELECT * FROM customer_table
JOIN billing_table ON customer_table.customerid = billing_table.customerid
JOIN service_table ON customer_table.customerid = service_table.customerid
JOIN streaming_table ON customer_table.customerid = streaming_table.customerid
JOIN security_table ON customer_table.customerid = security_table.customerid"""
telco_data = pd.read_sql_query(query, engine)

# %%
telco_data.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents id  customerid  \
# 0  7590-VHVEG  Female              0     Yes         No  1  7590-VHVEG
# 1  5575-GNVDE    Male              0      No         No  2  5575-GNVDE
# 2  3668-QPYBK    Male              0      No         No  3  3668-QPYBK
# 3  7795-CFOCW    Male              0      No         No  4  7795-CFOCW
# 4  9237-HQITU  Female              0      No         No  5  9237-HQITU
#
#          contract paperlessbilling              paymentmethod  ... id  \
# 0  Month-to-month              Yes           Electronic check  ...  1
# 1        One year               No               Mailed check  ...  2
# 2  Month-to-month              Yes               Mailed check  ...  3
# 3        One year               No  Bank transfer (automatic)  ...  4
# 4  Month-to-month              Yes           Electronic check  ...  5
#
#    customerid streamingtv  streamingmovies id  customerid onlinesecurity  \
# 0  7590-VHVEG          No               No  1  7590-VHVEG             No
# 1  5575-GNVDE          No               No  2  5575-GNVDE            Yes
# 2  3668-QPYBK          No               No  3  3668-QPYBK            Yes
# 3  7795-CFOCW          No               No  4  7795-CFOCW            Yes
# 4  9237-HQITU          No               No  5  9237-HQITU             No
#
#   onlinebackup deviceprotection  techsupport
# 0          Yes               No           No
# 1           No              Yes           No
# 2          Yes               No           No
# 3           No              Yes          Yes
# 4           No               No           No
#
# [5 rows x 29 columns]

# %%
# Merge customer_data and billing_data
customer_billing = pd.merge(customer_data, billing_data, on='customerid', suffixes=('_left', '_right'))

# Merge the result with service_data
customer_billing_service = pd.merge(customer_billing, service_data, on='customerid', suffixes=('_left1', '_right1'))

# Merge the result with streaming_data
customer_billing_service_streaming = pd.merge(customer_billing_service, streaming_data, on='customerid', suffixes=('_left3', '_right3'))

# Finally, merge the result with security_data
customer_churn_data_combined = pd.merge(customer_billing_service_streaming, security_data, on='customerid', suffixes=('_left2', '_right2'))

# %%
customer_churn_data_combined.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  id_left1  \
# 0  0002-ORFBO  Female              0     Yes        Yes      2308
# 1  0003-MKNFE    Male              0      No         No      3489
# 2  0004-TLHLJ    Male              0      No         No      3846
# 3  0011-IGKFF    Male              1     Yes         No      5932
# 4  0013-EXCHZ  Female              1     Yes         No      5570
#
#          contract paperlessbilling     paymentmethod  monthlycharges  ...  \
# 0        One year              Yes      Mailed check            65.6  ...
# 1  Month-to-month               No      Mailed check            59.9  ...
# 2  Month-to-month              Yes  Electronic check            73.9  ...
# 3  Month-to-month              Yes  Electronic check            98.0  ...
# 4  Month-to-month              Yes      Mailed check            83.9  ...
#
#    multiplelines internetservice  id_left2  streamingtv streamingmovies  \
# 0             No             DSL      2308          Yes              No
# 1            Yes             DSL      3489           No             Yes
# 2             No     Fiber optic      3846           No              No
# 3             No     Fiber optic      5932          Yes             Yes
# 4             No     Fiber optic      5570          Yes              No
#
#   id_right2 onlinesecurity  onlinebackup deviceprotection techsupport
# 0      2308             No           Yes               No         Yes
# 1      3489             No            No               No          No
# 2      3846             No            No              Yes          No
# 3      5932             No           Yes              Yes          No
# 4      5570             No            No               No         Yes
#
# [5 rows x 25 columns]

# %%
customer_churn_data_combined.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  id_left1  \
# 0  0002-ORFBO  Female              0     Yes        Yes      2308
# 1  0003-MKNFE    Male              0      No         No      3489
# 2  0004-TLHLJ    Male              0      No         No      3846
# 3  0011-IGKFF    Male              1     Yes         No      5932
# 4  0013-EXCHZ  Female              1     Yes         No      5570
#
#          contract paperlessbilling     paymentmethod  monthlycharges  ...  \
# 0        One year              Yes      Mailed check            65.6  ...
# 1  Month-to-month               No      Mailed check            59.9  ...
# 2  Month-to-month              Yes  Electronic check            73.9  ...
# 3  Month-to-month              Yes  Electronic check            98.0  ...
# 4  Month-to-month              Yes      Mailed check            83.9  ...
#
#    multiplelines internetservice  id_left2  streamingtv streamingmovies  \
# 0             No             DSL      2308          Yes              No
# 1            Yes             DSL      3489           No             Yes
# 2             No     Fiber optic      3846           No              No
# 3             No     Fiber optic      5932          Yes             Yes
# 4             No     Fiber optic      5570          Yes              No
#
#   id_right2 onlinesecurity  onlinebackup deviceprotection techsupport
# 0      2308             No           Yes               No         Yes
# 1      3489             No            No               No          No
# 2      3846             No            No              Yes          No
# 3      5932             No           Yes              Yes          No
# 4      5570             No            No               No         Yes
#
# [5 rows x 25 columns]

# %%
customer_billing = pd.merge(customer_data, billing_data, on='customerid')

# %%
customer_billing.shape
# Out:
# (7043, 12)

# %%
customer_billing = customer_billing.drop(['customerid', 'id'], axis=1)

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Column Value Transformation</title>
# </head>
# <body>
#     <h1>Transforming Column Values</h1>
#     <p>Handling the categorical data in the columns contract and payment method.</p>
# </body>
# </html>

# %%
customer_billing.sample(5)
# Out:
#       gender  seniorcitizen partner dependents        contract  \
# 4709  Female              0      No         No  Month-to-month
# 5184  Female              0      No         No  Month-to-month
# 5978  Female              0     Yes         No        One year
# 5639  Female              0     Yes        Yes        Two year
# 1603  Female              0      No         No        One year
#
#      paperlessbilling              paymentmethod  monthlycharges  \
# 4709               No  Bank transfer (automatic)           83.20
# 5184               No           Electronic check           90.55
# 5978               No    Credit card (automatic)           20.70
# 5639              Yes               Mailed check           24.50
# 1603               No    Credit card (automatic)           25.05
#
#       totalcharges churn
# 4709       2032.30    No
# 5184         90.55   Yes
# 5978       1032.05    No
# 5639        740.30   Yes
# 1603       1171.50    No

# %%
customer_billing = pd.get_dummies(customer_billing, columns=['contract', 'paymentmethod'], drop_first=True)

# %%
customer_billing.head()
# Out:
#    gender  seniorcitizen partner dependents paperlessbilling  monthlycharges  \
# 0  Female              0     Yes        Yes              Yes            65.6
# 1    Male              0      No         No               No            59.9
# 2    Male              0      No         No              Yes            73.9
# 3    Male              1     Yes         No              Yes            98.0
# 4  Female              1     Yes         No              Yes            83.9
#
#    totalcharges churn  contract_One year  contract_Two year  \
# 0        593.30    No               True              False
# 1        542.40    No              False              False
# 2        280.85   Yes              False              False
# 3       1237.85   Yes              False              False
# 4        267.40   Yes              False              False
#
#    paymentmethod_Credit card (automatic)  paymentmethod_Electronic check  \
# 0                                  False                           False
# 1                                  False                           False
# 2                                  False                            True
# 3                                  False                            True
# 4                                  False                           False
#
#    paymentmethod_Mailed check
# 0                        True
# 1                        True
# 2                       False
# 3                       False
# 4                        True

# %%
customer_billing = pd.get_dummies(customer_billing, columns=["churn"], drop_first=True)

# %%
customer_billing.head()
# Out:
#    gender  seniorcitizen partner dependents paperlessbilling  monthlycharges  \
# 0  Female              0     Yes        Yes              Yes            65.6
# 1    Male              0      No         No               No            59.9
# 2    Male              0      No         No              Yes            73.9
# 3    Male              1     Yes         No              Yes            98.0
# 4  Female              1     Yes         No              Yes            83.9
#
#    totalcharges  contract_One year  contract_Two year  \
# 0        593.30               True              False
# 1        542.40              False              False
# 2        280.85              False              False
# 3       1237.85              False              False
# 4        267.40              False              False
#
#    paymentmethod_Credit card (automatic)  paymentmethod_Electronic check  \
# 0                                  False                           False
# 1                                  False                           False
# 2                                  False                            True
# 3                                  False                            True
# 4                                  False                           False
#
#    paymentmethod_Mailed check  churn_Yes
# 0                        True      False
# 1                        True      False
# 2                       False       True
# 3                       False       True
# 4                        True       True

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Data Preprocessing dummies</title>
# </head>
# <body>
#     <h1>Data Preprocessing for Machine Learning</h1>
#     <p>In the current project, we are dealing with a dataset that contains categorical data. Categorical data is a type of data that can take on one of a limited number of categories. For example, in our dataset, the 'contract' and 'paymentmethod' columns contain various categories.</p>
#     <p>Most machine learning algorithms require numerical input and output variables. So, we need to convert these categorical data into a numerical format. One common technique for this conversion is called one-hot encoding.</p>
#     <p>In pandas, the <code>get_dummies</code> function is used to convert categorical variable(s) into dummy/indicator variables. For each unique value in the categorical column, it creates a new column that represents whether the record has that value. If the record has that value, it will be 1, otherwise it will be 0.</p>
#     <p>Here's how we can apply this in our project:</p>
#     <pre>
#     <code>
#     customer_billing = pd.get_dummies(customer_billing, columns=["partner", "dependants", "paperlessbilling"], drop_first=True)
#     </code>
#     </pre>
#     <p>The <code>drop_first=True</code> argument is used to avoid the dummy variable trap, which is a scenario in which the independent variables are multicollinear.</p>
# </body>
# </html>

# %%
customer_billing = pd.get_dummies(customer_billing, columns=["partner", "dependents", "paperlessbilling"], drop_first=True)

# %%
customer_billing.sample(5)
# Out:
#       gender  seniorcitizen  monthlycharges  totalcharges  contract_One year  \
# 91    Female              1          101.25       3949.15              False
# 6971  Female              0           74.30         74.30              False
# 5211  Female              0           19.50       1222.65              False
# 2899  Female              0           50.55        244.75              False
# 3389  Female              1           79.15       1520.90              False
#
#       contract_Two year  paymentmethod_Credit card (automatic)  \
# 91                False                                  False
# 6971              False                                   True
# 5211               True                                   True
# 2899              False                                  False
# 3389              False                                  False
#
#       paymentmethod_Electronic check  paymentmethod_Mailed check  churn_Yes  \
# 91                              True                       False      False
# 6971                           False                       False       True
# 5211                           False                       False      False
# 2899                           False                       False      False
# 3389                            True                       False       True
#
#       partner_Yes  dependents_Yes  paperlessbilling_Yes
# 91           True           False                  True
# 6971        False           False                  True
# 5211         True            True                 False
# 2899        False           False                 False
# 3389        False           False                  True

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Conducting exploratory analysis</title>
# </head>
# <body>
#     <h1>Exploratory Data Analysis</h1>
#     <p>Exploratory data analysis (EDA) is an approach to analyzing datasets to summarize their main characteristics, often with visual methods. It helps us to understand the data, discover patterns, spot anomalies, and check assumptions.</p>
#     <p>Here are some common techniques used in EDA:</p>
#     <ul>
#         <li>Descriptive statistics: Summarizing the data using its key characteristics, such as the mean, median, mode, standard deviation, and range.</li>
#         <li>Grouping data: Using aggregation and grouping methods to understand the relationships between variables.</li>
#         <li>Data visualization: Creating charts, plots, and graphs to visually represent the data.</li>
#         <li>Correlation analysis: Examining the relationships between variables to identify patterns and trends.</li>
#     </ul>
#     <p>Let's conduct some exploratory analysis on our dataset to understand the relationships between different variables.</p>

# %%
import matplotlib.pyplot as plt

# %%
#total customers
customer_count = len(customer_billing['churn_Yes'])
churned = len(customer_billing[customer_billing['churn_Yes'] == 1])
not_churned = len(customer_billing[customer_billing['churn_Yes'] == 0])

# %%
print ("churned : {},\n not_churned {} \n total customers: {}".format(churned, not_churned, customer_count))
# Out:
# churned : 1869,
#  not_churned 5174
#  total customers: 7043

# %%
category = ['Churned', 'Not Churned']
values = [(churned * 100 / customer_count), (not_churned * 100 / customer_count)]
bars = plt.bar(category, values)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.title('Customer Churn')
plt.show()

# %%
# summary of table data
customer_billing.describe()
# Out:
#        seniorcitizen  monthlycharges  totalcharges
# count    7043.000000     7043.000000   7032.000000
# mean        0.162147       64.761692   2283.300441
# std         0.368612       30.090047   2266.771362
# min         0.000000       18.250000     18.800000
# 25%         0.000000       35.500000    401.450000
# 50%         0.000000       70.350000   1397.475000
# 75%         0.000000       89.850000   3794.737500
# max         1.000000      118.750000   8684.800000

# %%
telco = customer_churn_data_combined.copy()

# %%
telco.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  id_left1  \
# 0  0002-ORFBO  Female              0     Yes        Yes      2308
# 1  0003-MKNFE    Male              0      No         No      3489
# 2  0004-TLHLJ    Male              0      No         No      3846
# 3  0011-IGKFF    Male              1     Yes         No      5932
# 4  0013-EXCHZ  Female              1     Yes         No      5570
#
#          contract paperlessbilling     paymentmethod  monthlycharges  ...  \
# 0        One year              Yes      Mailed check            65.6  ...
# 1  Month-to-month               No      Mailed check            59.9  ...
# 2  Month-to-month              Yes  Electronic check            73.9  ...
# 3  Month-to-month              Yes  Electronic check            98.0  ...
# 4  Month-to-month              Yes      Mailed check            83.9  ...
#
#    multiplelines internetservice  id_left2  streamingtv streamingmovies  \
# 0             No             DSL      2308          Yes              No
# 1            Yes             DSL      3489           No             Yes
# 2             No     Fiber optic      3846           No              No
# 3             No     Fiber optic      5932          Yes             Yes
# 4             No     Fiber optic      5570          Yes              No
#
#   id_right2 onlinesecurity  onlinebackup deviceprotection techsupport
# 0      2308             No           Yes               No         Yes
# 1      3489             No            No               No          No
# 2      3846             No            No              Yes          No
# 3      5932             No           Yes              Yes          No
# 4      5570             No            No               No         Yes
#
# [5 rows x 25 columns]

# %%
#display all telco columns
telco.columns
# drop id_left1, id_right1,  id_left2, id_right2
telco = telco.drop(['id_left1', 'id_right1', 'id_left2', 'id_right2'], axis=1)

# %%
telco.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents        contract  \
# 0  0002-ORFBO  Female              0     Yes        Yes        One year
# 1  0003-MKNFE    Male              0      No         No  Month-to-month
# 2  0004-TLHLJ    Male              0      No         No  Month-to-month
# 3  0011-IGKFF    Male              1     Yes         No  Month-to-month
# 4  0013-EXCHZ  Female              1     Yes         No  Month-to-month
#
#   paperlessbilling     paymentmethod  monthlycharges  totalcharges  ...  \
# 0              Yes      Mailed check            65.6        593.30  ...
# 1               No      Mailed check            59.9        542.40  ...
# 2              Yes  Electronic check            73.9        280.85  ...
# 3              Yes  Electronic check            98.0       1237.85  ...
# 4              Yes      Mailed check            83.9        267.40  ...
#
#   tenure  phoneservice multiplelines internetservice streamingtv  \
# 0      9           Yes            No             DSL         Yes
# 1      9           Yes           Yes             DSL          No
# 2      4           Yes            No     Fiber optic          No
# 3     13           Yes            No     Fiber optic         Yes
# 4      3           Yes            No     Fiber optic         Yes
#
#   streamingmovies onlinesecurity onlinebackup deviceprotection techsupport
# 0              No             No          Yes               No         Yes
# 1             Yes             No           No               No          No
# 2              No             No           No              Yes          No
# 3             Yes             No          Yes              Yes          No
# 4              No             No           No               No         Yes
#
# [5 rows x 21 columns]

# %%
telco.totalcharges = pd.to_numeric(telco.totalcharges, errors='coerce')
telco.isnull().sum()
# Out:
# customerid           0
# gender               0
# seniorcitizen        0
# partner              0
# dependents           0
# contract             0
# paperlessbilling     0
# paymentmethod        0
# monthlycharges       0
# totalcharges        11
# churn                0
# tenure               0
# phoneservice         0
# multiplelines        0
# internetservice      0
# streamingtv          0
# streamingmovies      0
# onlinesecurity       0
# onlinebackup         0
# deviceprotection     0
# techsupport          0
# dtype: int64

# %%
telco.loc[telco.totalcharges.isnull() == True]
# Out:
#       customerid  gender  seniorcitizen partner dependents  contract  \
# 945   1371-DWPAZ  Female              0     Yes        Yes  Two year
# 1731  2520-SGTTA  Female              0     Yes        Yes  Two year
# 1906  2775-SEFEE    Male              0      No        Yes  Two year
# 2025  2923-ARZLG    Male              0     Yes        Yes  One year
# 2176  3115-CZMZD    Male              0      No        Yes  Two year
# 2250  3213-VVOLG    Male              0     Yes        Yes  Two year
# 2855  4075-WKNIU  Female              0     Yes        Yes  Two year
# 3052  4367-NUYAO    Male              0     Yes        Yes  Two year
# 3118  4472-LVYGI  Female              0     Yes        Yes  Two year
# 4054  5709-LVOEQ  Female              0     Yes        Yes  Two year
# 5433  7644-OMVMY    Male              0     Yes        Yes  Two year
#
#      paperlessbilling              paymentmethod  monthlycharges  \
# 945                No    Credit card (automatic)           56.05
# 1731               No               Mailed check           20.00
# 1906              Yes  Bank transfer (automatic)           61.90
# 2025              Yes               Mailed check           19.70
# 2176               No               Mailed check           20.25
# 2250               No               Mailed check           25.35
# 2855               No               Mailed check           73.35
# 3052               No               Mailed check           25.75
# 3118              Yes  Bank transfer (automatic)           52.55
# 4054               No               Mailed check           80.85
# 5433               No               Mailed check           19.85
#
#       totalcharges  ... tenure  phoneservice     multiplelines  \
# 945            NaN  ...      0            No  No phone service
# 1731           NaN  ...      0           Yes                No
# 1906           NaN  ...      0           Yes               Yes
# 2025           NaN  ...      0           Yes                No
# 2176           NaN  ...      0           Yes                No
# 2250           NaN  ...      0           Yes               Yes
# 2855           NaN  ...      0           Yes               Yes
# 3052           NaN  ...      0           Yes               Yes
# 3118           NaN  ...      0            No  No phone service
# 4054           NaN  ...      0           Yes                No
# 5433           NaN  ...      0           Yes                No
#
#      internetservice          streamingtv      streamingmovies  \
# 945              DSL                  Yes                   No
# 1731              No  No internet service  No internet service
# 1906             DSL                   No                   No
# 2025              No  No internet service  No internet service
# 2176              No  No internet service  No internet service
# 2250              No  No internet service  No internet service
# 2855             DSL                  Yes                   No
# 3052              No  No internet service  No internet service
# 3118             DSL                  Yes                   No
# 4054             DSL                  Yes                  Yes
# 5433              No  No internet service  No internet service
#
#            onlinesecurity         onlinebackup     deviceprotection  \
# 945                   Yes                  Yes                  Yes
# 1731  No internet service  No internet service  No internet service
# 1906                  Yes                  Yes                   No
# 2025  No internet service  No internet service  No internet service
# 2176  No internet service  No internet service  No internet service
# 2250  No internet service  No internet service  No internet service
# 2855                   No                  Yes                  Yes
# 3052  No internet service  No internet service  No internet service
# 3118                  Yes                   No                  Yes
# 4054                  Yes                  Yes                  Yes
# 5433  No internet service  No internet service  No internet service
#
#               techsupport
# 945                   Yes
# 1731  No internet service
# 1906                  Yes
# 2025  No internet service
# 2176  No internet service
# 2250  No internet service
# 2855                  Yes
# 3052  No internet service
# 3118                  Yes
# 4054                   No
# 5433  No internet service
#
# [11 rows x 21 columns]

# %%
telco.dropna(how='any', inplace=True)

# %%
# We will create a category group for tenure check the max tenure
print(telco['tenure'].max())
# Out:
# 72

# %%
labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]
telco['tenure_group'] = pd.cut(telco.tenure, range(1, 80, 12), right=False, labels=labels)

# %%
print(labels)
# Out:
# ['1 - 12', '13 - 24', '25 - 36', '37 - 48', '49 - 60', '61 - 72']

# %%
telco['tenure_group'].value_counts()
# Out:
# tenure_group
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: count, dtype: int64

# %%
# Remove columns we dont need for the model
telco.drop(columns=['customerid', 'tenure'], axis=1, inplace=True)

# %%
telco.head()
# Out:
#    gender  seniorcitizen partner dependents        contract paperlessbilling  \
# 0  Female              0     Yes        Yes        One year              Yes
# 1    Male              0      No         No  Month-to-month               No
# 2    Male              0      No         No  Month-to-month              Yes
# 3    Male              1     Yes         No  Month-to-month              Yes
# 4  Female              1     Yes         No  Month-to-month              Yes
#
#       paymentmethod  monthlycharges  totalcharges churn phoneservice  \
# 0      Mailed check            65.6        593.30    No          Yes
# 1      Mailed check            59.9        542.40    No          Yes
# 2  Electronic check            73.9        280.85   Yes          Yes
# 3  Electronic check            98.0       1237.85   Yes          Yes
# 4      Mailed check            83.9        267.40   Yes          Yes
#
#   multiplelines internetservice streamingtv streamingmovies onlinesecurity  \
# 0            No             DSL         Yes              No             No
# 1           Yes             DSL          No             Yes             No
# 2            No     Fiber optic          No              No             No
# 3            No     Fiber optic         Yes             Yes             No
# 4            No     Fiber optic         Yes              No             No
#
#   onlinebackup deviceprotection techsupport tenure_group
# 0          Yes               No         Yes       1 - 12
# 1           No               No          No       1 - 12
# 2           No              Yes          No       1 - 12
# 3          Yes              Yes          No      13 - 24
# 4           No               No         Yes       1 - 12

# %%
import seaborn as sns
for i, predictor in enumerate(telco.drop(columns=['churn', 'totalcharges', 'monthlycharges'])):
    plt.figure(i)
    sns.countplot(data=telco, x=predictor, hue='churn')

# %%
# Conver the churn to binary with 1 as yes and 0 as no
import numpy as np
telco['churn'] = np.where(telco.churn == 'Yes', 1, 0)

# %%
telco.head()
# Out:
#    gender  seniorcitizen partner dependents        contract paperlessbilling  \
# 0  Female              0     Yes        Yes        One year              Yes
# 1    Male              0      No         No  Month-to-month               No
# 2    Male              0      No         No  Month-to-month              Yes
# 3    Male              1     Yes         No  Month-to-month              Yes
# 4  Female              1     Yes         No  Month-to-month              Yes
#
#       paymentmethod  monthlycharges  totalcharges  churn phoneservice  \
# 0      Mailed check            65.6        593.30      0          Yes
# 1      Mailed check            59.9        542.40      0          Yes
# 2  Electronic check            73.9        280.85      1          Yes
# 3  Electronic check            98.0       1237.85      1          Yes
# 4      Mailed check            83.9        267.40      1          Yes
#
#   multiplelines internetservice streamingtv streamingmovies onlinesecurity  \
# 0            No             DSL         Yes              No             No
# 1           Yes             DSL          No             Yes             No
# 2            No     Fiber optic          No              No             No
# 3            No     Fiber optic         Yes             Yes             No
# 4            No     Fiber optic         Yes              No             No
#
#   onlinebackup deviceprotection techsupport tenure_group
# 0          Yes               No         Yes       1 - 12
# 1           No               No          No       1 - 12
# 2           No              Yes          No       1 - 12
# 3          Yes              Yes          No      13 - 24
# 4           No               No         Yes       1 - 12

# %%
# convert categorical data to using dummy library
telco_dummies = pd.get_dummies(telco)
telco_dummies.head()
# Out:
#    seniorcitizen  monthlycharges  totalcharges  churn  gender_Female  \
# 0              0            65.6        593.30      0           True
# 1              0            59.9        542.40      0          False
# 2              0            73.9        280.85      1          False
# 3              1            98.0       1237.85      1          False
# 4              1            83.9        267.40      1           True
#
#    gender_Male  partner_No  partner_Yes  dependents_No  dependents_Yes  ...  \
# 0        False       False         True          False            True  ...
# 1         True        True        False           True           False  ...
# 2         True        True        False           True           False  ...
# 3         True       False         True           True           False  ...
# 4        False       False         True           True           False  ...
#
#    deviceprotection_Yes  techsupport_No  techsupport_No internet service  \
# 0                 False           False                            False
# 1                 False            True                            False
# 2                  True            True                            False
# 3                  True            True                            False
# 4                 False           False                            False
#
#    techsupport_Yes  tenure_group_1 - 12  tenure_group_13 - 24  \
# 0             True                 True                 False
# 1            False                 True                 False
# 2            False                 True                 False
# 3            False                False                  True
# 4             True                 True                 False
#
#    tenure_group_25 - 36  tenure_group_37 - 48  tenure_group_49 - 60  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    tenure_group_61 - 72
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 51 columns]

# %%
# motnly charges and total relationship
sns.lmplot(data=telco, x='monthlycharges', y='totalcharges', fit_reg=False)

# %%
Mth = sns.kdeplot(telco_dummies.monthlycharges[(telco_dummies["churn"] == 0) ],
                color="Red", fill = True)
Mth = sns.kdeplot(telco_dummies.monthlycharges[(telco_dummies["churn"] == 1) ],
                ax =Mth, color="Blue", fill= True)
Mth.legend(["No Churn","Churn"],loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('Monthly Charges')
Mth.set_title('Monthly charges by churn')
# Out:
# Text(0.5, 1.0, 'Monthly charges by churn')

# %%
Tot = sns.kdeplot(telco_dummies.totalcharges[(telco_dummies["churn"] == 0) ],
                color="Red", fill = True)
Tot = sns.kdeplot(telco_dummies.totalcharges[(telco_dummies["churn"] == 1) ],
                ax =Tot, color="Blue", fill= True)
Tot.legend(["No Churn","Churn"],loc='upper right')
Tot.set_ylabel('Density')
Tot.set_xlabel('Total Charges')
Tot.set_title('Total charges by churn')
# Out:
# Text(0.5, 1.0, 'Total charges by churn')

# %%
plt.figure(figsize=(20,8))
telco_dummies.corr()['churn'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %%
new_df1_target0=telco.loc[telco["churn"]==0]
new_df1_target1=telco.loc[telco["churn"]==1]

# %%
def uniplot(df,col,title,hue =None):

    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30

    temp = pd.Series(data = hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())
    fig.set_size_inches(width , 8)
    plt.xticks(rotation=45)
    # plt.yscale('log')  # Commented out to set y-axis scale to linear
    plt.title(title)
    ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue,palette='bright')

    plt.show()

# %%
uniplot(new_df1_target1,col='partner',title='Distribution of Gender for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target0,col='partner',title='Distribution of Gender for Non Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='paymentmethod',title='Distribution of PaymentMethod for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='contract',title='Distribution of Contract for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='techsupport',title='Distribution of TechSupport for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='seniorcitizen',title='Distribution of SeniorCitizen for Churned Customers',hue='gender')

# %%
telco_dummies.to_csv('tel_churn.csv')
