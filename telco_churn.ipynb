# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://shvmpz:Pioneer.254@localhost:3306/telco_churn')

# %%
tables = pd.read_sql_query("SHOW TABLES", engine)
tables.head()
# Out:
#   Tables_in_telco_churn
# 0         billing_table
# 1        customer_table
# 2        security_table
# 3         service_table
# 4       streaming_table

# %%
customer_data = pd.read_sql_query("SELECT * FROM customer_table", engine)
billing_data = pd.read_sql_query("SELECT * FROM billing_table", engine)
service_data = pd.read_sql_query("SELECT * FROM service_table", engine)
streaming_data = pd.read_sql_query("SELECT * FROM streaming_table", engine)
security_data = pd.read_sql_query("SELECT * FROM security_table", engine)
query = """SELECT * FROM customer_table
JOIN billing_table ON customer_table.customerid = billing_table.customerid
JOIN service_table ON customer_table.customerid = service_table.customerid
JOIN streaming_table ON customer_table.customerid = streaming_table.customerid
JOIN security_table ON customer_table.customerid = security_table.customerid"""
telco_data = pd.read_sql_query(query, engine)

# %%
telco_data.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents    id  customerid  \
# 0  0002-ORFBO  Female              0     Yes        Yes  2308  0002-ORFBO
# 1  0003-MKNFE    Male              0      No         No  3489  0003-MKNFE
# 2  0004-TLHLJ    Male              0      No         No  3846  0004-TLHLJ
# 3  0011-IGKFF    Male              1     Yes         No  5932  0011-IGKFF
# 4  0013-EXCHZ  Female              1     Yes         No  5570  0013-EXCHZ
#
#          contract paperlessbilling     paymentmethod  ...    id  customerid  \
# 0        One year              Yes      Mailed check  ...  2308  0002-ORFBO
# 1  Month-to-month               No      Mailed check  ...  3489  0003-MKNFE
# 2  Month-to-month              Yes  Electronic check  ...  3846  0004-TLHLJ
# 3  Month-to-month              Yes  Electronic check  ...  5932  0011-IGKFF
# 4  Month-to-month              Yes      Mailed check  ...  5570  0013-EXCHZ
#
#   streamingtv  streamingmovies    id  customerid onlinesecurity onlinebackup  \
# 0         Yes               No  2308  0002-ORFBO             No          Yes
# 1          No              Yes  3489  0003-MKNFE             No           No
# 2          No               No  3846  0004-TLHLJ             No           No
# 3         Yes              Yes  5932  0011-IGKFF             No          Yes
# 4         Yes               No  5570  0013-EXCHZ             No           No
#
#   deviceprotection  techsupport
# 0               No          Yes
# 1               No           No
# 2              Yes           No
# 3              Yes           No
# 4               No          Yes
#
# [5 rows x 29 columns]

# %%
# Merge customer_data and billing_data
customer_billing = pd.merge(customer_data, billing_data, on='customerid', suffixes=('_left', '_right'))

# Merge the result with service_data
customer_billing_service = pd.merge(customer_billing, service_data, on='customerid', suffixes=('_left1', '_right1'))

# Merge the result with streaming_data
customer_billing_service_streaming = pd.merge(customer_billing_service, streaming_data, on='customerid', suffixes=('_left3', '_right3'))

# Finally, merge the result with security_data
customer_churn_data_combined = pd.merge(customer_billing_service_streaming, security_data, on='customerid', suffixes=('_left2', '_right2'))

# %%
customer_churn_data_combined.head
# Out:
# <bound method NDFrame.head of       customerid  gender  seniorcitizen partner dependents  id_left1  \
# 0     0002-ORFBO  Female              0     Yes        Yes      2308
# 1     0003-MKNFE    Male              0      No         No      3489
# 2     0004-TLHLJ    Male              0      No         No      3846
# 3     0011-IGKFF    Male              1     Yes         No      5932
# 4     0013-EXCHZ  Female              1     Yes         No      5570
# ...          ...     ...            ...     ...        ...       ...
# 7038  9987-LUTYD  Female              0      No         No      3608
# 7039  9992-RRAMN    Male              0     Yes         No      2876
# 7040  9992-UJOEL    Male              0      No         No      1261
# 7041  9993-LHIEB    Male              0     Yes        Yes      1997
# 7042  9995-HOTOH    Male              0     Yes        Yes      1635
#
#             contract paperlessbilling     paymentmethod  monthlycharges  ...  \
# 0           One year              Yes      Mailed check           65.60  ...
# 1     Month-to-month               No      Mailed check           59.90  ...
# 2     Month-to-month              Yes  Electronic check           73.90  ...
# 3     Month-to-month              Yes  Electronic check           98.00  ...
# 4     Month-to-month              Yes      Mailed check           83.90  ...
# ...              ...              ...               ...             ...  ...
# 7038        One year               No      Mailed check           55.15  ...
# 7039  Month-to-month              Yes  Electronic check           85.10  ...
# 7040  Month-to-month              Yes      Mailed check           50.30  ...
# 7041        Two year               No      Mailed check           67.85  ...
# 7042        Two year               No  Electronic check           59.00  ...
#
#          multiplelines internetservice  id_left2  streamingtv streamingmovies  \
# 0                   No             DSL      2308          Yes              No
# 1                  Yes             DSL      3489           No             Yes
# 2                   No     Fiber optic      3846           No              No
# 3                   No     Fiber optic      5932          Yes             Yes
# 4                   No     Fiber optic      5570          Yes              No
# ...                ...             ...       ...          ...             ...
# 7038                No             DSL      3608           No              No
# 7039               Yes     Fiber optic      2876           No             Yes
# 7040                No             DSL      1261           No              No
# 7041                No             DSL      1997           No             Yes
# 7042  No phone service             DSL      1635          Yes             Yes
#
#      id_right2 onlinesecurity  onlinebackup deviceprotection techsupport
# 0         2308             No           Yes               No         Yes
# 1         3489             No            No               No          No
# 2         3846             No            No              Yes          No
# 3         5932             No           Yes              Yes          No
# 4         5570             No            No               No         Yes
# ...        ...            ...           ...              ...         ...
# 7038      3608            Yes            No               No         Yes
# 7039      2876             No            No               No          No
# 7040      1261             No           Yes               No          No
# 7041      1997            Yes            No              Yes         Yes
# 7042      1635            Yes           Yes              Yes          No
#
# [7043 rows x 25 columns]>

# %%
customer_churn_data_combined.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  id_left1  \
# 0  0002-ORFBO  Female              0     Yes        Yes      2308
# 1  0003-MKNFE    Male              0      No         No      3489
# 2  0004-TLHLJ    Male              0      No         No      3846
# 3  0011-IGKFF    Male              1     Yes         No      5932
# 4  0013-EXCHZ  Female              1     Yes         No      5570
#
#          contract paperlessbilling     paymentmethod  monthlycharges  ...  \
# 0        One year              Yes      Mailed check            65.6  ...
# 1  Month-to-month               No      Mailed check            59.9  ...
# 2  Month-to-month              Yes  Electronic check            73.9  ...
# 3  Month-to-month              Yes  Electronic check            98.0  ...
# 4  Month-to-month              Yes      Mailed check            83.9  ...
#
#    multiplelines internetservice  id_left2  streamingtv streamingmovies  \
# 0             No             DSL      2308          Yes              No
# 1            Yes             DSL      3489           No             Yes
# 2             No     Fiber optic      3846           No              No
# 3             No     Fiber optic      5932          Yes             Yes
# 4             No     Fiber optic      5570          Yes              No
#
#   id_right2 onlinesecurity  onlinebackup deviceprotection techsupport
# 0      2308             No           Yes               No         Yes
# 1      3489             No            No               No          No
# 2      3846             No            No              Yes          No
# 3      5932             No           Yes              Yes          No
# 4      5570             No            No               No         Yes
#
# [5 rows x 25 columns]

# %%
customer_billing = pd.merge(customer_data, billing_data, on='customerid')

# %%
customer_billing.shape
# Out:
# (7043, 12)

# %%
customer_billing = customer_billing.drop(['customerid', 'id'], axis=1)

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Column Value Transformation</title>
# </head>
# <body>
#     <h1>Transforming Column Values</h1>
#     <p>Handling the categorical data in the columns contract and payment method.</p>
# </body>
# </html>

# %%
customer_billing.sample(5)
# Out:
#       gender  seniorcitizen partner dependents        contract  \
# 5976  Female              1     Yes        Yes  Month-to-month
# 2487    Male              0     Yes        Yes        Two year
# 2991    Male              0      No         No  Month-to-month
# 4348  Female              0     Yes        Yes  Month-to-month
# 4789    Male              0      No         No        Two year
#
#      paperlessbilling            paymentmethod  monthlycharges  totalcharges  \
# 5976              Yes  Credit card (automatic)           95.30       5567.45
# 2487               No  Credit card (automatic)           62.65       4375.80
# 2991               No             Mailed check           64.95        547.80
# 4348               No             Mailed check           20.20        382.20
# 4789              Yes         Electronic check          108.95       4025.50
#
#      churn
# 5976    No
# 2487    No
# 2991    No
# 4348    No
# 4789    No

# %%
customer_billing = pd.get_dummies(customer_billing, columns=['contract', 'paymentmethod'], drop_first=True)

# %%
customer_billing.sample(5)
# Out:
#       gender  seniorcitizen partner dependents paperlessbilling  \
# 4293    Male              0     Yes         No              Yes
# 5662    Male              0      No         No              Yes
# 634     Male              0      No         No              Yes
# 673   Female              0     Yes         No              Yes
# 6215  Female              0      No         No              Yes
#
#       monthlycharges  totalcharges churn  contract_One year  \
# 4293           19.75        899.45    No              False
# 5662           90.55       2282.55   Yes              False
# 634            50.15        160.85    No              False
# 673            51.45       1758.90    No               True
# 6215           99.85       1776.95   Yes              False
#
#       contract_Two year  paymentmethod_Credit card (automatic)  \
# 4293               True                                  False
# 5662              False                                   True
# 634               False                                  False
# 673               False                                  False
# 6215              False                                  False
#
#       paymentmethod_Electronic check  paymentmethod_Mailed check
# 4293                            True                       False
# 5662                           False                       False
# 634                            False                        True
# 673                            False                        True
# 6215                           False                       False

# %%
customer_billing = pd.get_dummies(customer_billing, columns=["churn"], drop_first=True)

# %%
customer_billing.sample(5)
# Out:
#       gender  seniorcitizen partner dependents paperlessbilling  \
# 6632  Female              0      No         No               No
# 1579  Female              1     Yes         No               No
# 3698    Male              0      No         No              Yes
# 5841  Female              0     Yes        Yes              Yes
# 458     Male              0      No         No               No
#
#       monthlycharges  totalcharges  contract_One year  contract_Two year  \
# 6632           18.75         53.15              False              False
# 1579          117.45       5438.90              False              False
# 3698           39.65        733.35              False              False
# 5841          100.40       4303.65              False               True
# 458            20.45         20.45              False              False
#
#       paymentmethod_Credit card (automatic)  paymentmethod_Electronic check  \
# 6632                                  False                           False
# 1579                                  False                            True
# 3698                                  False                            True
# 5841                                  False                            True
# 458                                   False                           False
#
#       paymentmethod_Mailed check  churn_Yes
# 6632                       False      False
# 1579                       False       True
# 3698                       False       True
# 5841                       False      False
# 458                         True      False

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Data Preprocessing dummies</title>
# </head>
# <body>
#     <h1>Data Preprocessing for Machine Learning</h1>
#     <p>In the current project, we are dealing with a dataset that contains categorical data. Categorical data is a type of data that can take on one of a limited number of categories. For example, in our dataset, the 'contract' and 'paymentmethod' columns contain various categories.</p>
#     <p>Most machine learning algorithms require numerical input and output variables. So, we need to convert these categorical data into a numerical format. One common technique for this conversion is called one-hot encoding.</p>
#     <p>In pandas, the <code>get_dummies</code> function is used to convert categorical variable(s) into dummy/indicator variables. For each unique value in the categorical column, it creates a new column that represents whether the record has that value. If the record has that value, it will be 1, otherwise it will be 0.</p>
#     <p>Here's how we can apply this in our project:</p>
#     <pre>
#     <code>
#     customer_billing = pd.get_dummies(customer_billing, columns=["partner", "dependants", "paperlessbilling"], drop_first=True)
#     </code>
#     </pre>
#     <p>The <code>drop_first=True</code> argument is used to avoid the dummy variable trap, which is a scenario in which the independent variables are multicollinear.</p>
# </body>
# </html>

# %%
customer_billing = pd.get_dummies(customer_billing, columns=["partner", "dependents", "paperlessbilling"], drop_first=True)

# %%
customer_billing.sample(5)
# Out:
#       gender  seniorcitizen  monthlycharges  totalcharges  contract_One year  \
# 2810  Female              0           49.75       3069.45              False
# 4443    Male              0           19.70        117.80               True
# 5995    Male              0           78.70       1495.10              False
# 1539    Male              0           81.05       5135.35              False
# 4832    Male              0          104.85       3887.25               True
#
#       contract_Two year  paymentmethod_Credit card (automatic)  \
# 2810              False                                  False
# 4443              False                                  False
# 5995              False                                  False
# 1539              False                                  False
# 4832              False                                  False
#
#       paymentmethod_Electronic check  paymentmethod_Mailed check  churn_Yes  \
# 2810                            True                       False      False
# 4443                           False                        True      False
# 5995                           False                       False      False
# 1539                            True                       False      False
# 4832                            True                       False      False
#
#       partner_Yes  dependents_Yes  paperlessbilling_Yes
# 2810         True            True                  True
# 4443        False           False                 False
# 5995        False           False                  True
# 1539         True            True                 False
# 4832        False           False                  True

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Conducting exploratory analysis</title>
# </head>
# <body>
#     <h1>Exploratory Data Analysis</h1>
#     <p>Exploratory data analysis (EDA) is an approach to analyzing datasets to summarize their main characteristics, often with visual methods. It helps us to understand the data, discover patterns, spot anomalies, and check assumptions.</p>
#     <p>Here are some common techniques used in EDA:</p>
#     <ul>
#         <li>Descriptive statistics: Summarizing the data using its key characteristics, such as the mean, median, mode, standard deviation, and range.</li>
#         <li>Grouping data: Using aggregation and grouping methods to understand the relationships between variables.</li>
#         <li>Data visualization: Creating charts, plots, and graphs to visually represent the data.</li>
#         <li>Correlation analysis: Examining the relationships between variables to identify patterns and trends.</li>
#     </ul>
#     <p>Let's conduct some exploratory analysis on our dataset to understand the relationships between different variables.</p>

# %%
import sys
print(sys.executable)
# Out:
# /home/shvmpz/PycharmProjects/DATA-ENGINEERING/machine learning spark/venv/bin/python3

# %%
import os

# Get the matplotlib path
matplotlib_path = "C:\\Users\\shvmpz\\PycharmProjects\\pythonProject\\venv\\Lib\\site"

# Add the matplotlib path to the PYTHONPATH environment variable
os.environ["PYTHONPATH"] += os.pathsep + matplotlib_path

# Verify if the path has been added successfully
print(os.environ["PYTHONPATH"])
#print current working directory
print(os.getcwd())
# Out:
# /home/shvmpz/PycharmProjects/IS_project-II:C:\Users\shvmpz\PycharmProjects\pythonProject\venv\Lib\site:C:\Users\shvmpz\PycharmProjects\pythonProject\venv\Lib\site
# /home/shvmpz/PycharmProjects/IS_project-II

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#total customers
customer_count = len(customer_billing['churn_Yes'])
churned = len(customer_billing[customer_billing['churn_Yes'] == 1])
not_churned = len(customer_billing[customer_billing['churn_Yes'] == 0])

# %%
print ("churned : {},\n not_churned {} \n total customers: {}".format(churned, not_churned, customer_count))
# Out:
# churned : 1869,
#  not_churned 5174
#  total customers: 7043

# %%
category = ['Churned', 'Not Churned']
values = [(churned * 100 / customer_count), (not_churned * 100 / customer_count)]
bars = plt.bar(category, values)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.title('Customer Churn')
plt.show()

# %%
# summary of table data
customer_billing.describe()
# Out:
#        seniorcitizen  monthlycharges  totalcharges
# count    7043.000000     7043.000000   7032.000000
# mean        0.162147       64.761692   2283.300441
# std         0.368612       30.090047   2266.771362
# min         0.000000       18.250000     18.800000
# 25%         0.000000       35.500000    401.450000
# 50%         0.000000       70.350000   1397.475000
# 75%         0.000000       89.850000   3794.737500
# max         1.000000      118.750000   8684.800000

# %%
telco = customer_churn_data_combined.copy()

# %%
telco = telco.drop(['id_right', 'id'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 telco = telco.drop(['id_right', 'id'], axis=1)
#
# File ~/PycharmProjects/DATA-ENGINEERING/machine learning spark/venv/lib/python3.11/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File ~/PycharmProjects/DATA-ENGINEERING/machine learning spark/venv/lib/python3.11/site-packages/pandas/core/generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File ~/PycharmProjects/DATA-ENGINEERING/machine learning spark/venv/lib/python3.11/site-packages/pandas/core/generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File ~/PycharmProjects/DATA-ENGINEERING/machine learning spark/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['id_right', 'id'] not found in axis"

# %%
telco.totalcharges = pd.to_numeric(telco.totalcharges, errors='coerce')
telco.isnull().sum()
# Out:
# customerid           0
# gender               0
# seniorcitizen        0
# partner              0
# dependents           0
# id_left1             0
# contract             0
# paperlessbilling     0
# paymentmethod        0
# monthlycharges       0
# totalcharges        11
# churn                0
# id_right1            0
# tenure               0
# phoneservice         0
# multiplelines        0
# internetservice      0
# id_left2             0
# streamingtv          0
# streamingmovies      0
# id_right2            0
# onlinesecurity       0
# onlinebackup         0
# deviceprotection     0
# techsupport          0
# dtype: int64

# %%
# drop unesecarry id columns
telco = telco.drop(['id_right2'], axis=1)

# %%
telco.loc[telco.totalcharges.isnull() == True]
# Out:
#       customerid  gender  seniorcitizen partner dependents  id_left1  \
# 945   1371-DWPAZ  Female              0     Yes        Yes      1341
# 1731  2520-SGTTA  Female              0     Yes        Yes      4381
# 1906  2775-SEFEE    Male              0      No        Yes      6755
# 2025  2923-ARZLG    Male              0     Yes        Yes      5219
# 2176  3115-CZMZD    Male              0      No        Yes       754
# 2250  3213-VVOLG    Male              0     Yes        Yes      3827
# 2855  4075-WKNIU  Female              0     Yes        Yes      6671
# 3052  4367-NUYAO    Male              0     Yes        Yes      1083
# 3118  4472-LVYGI  Female              0     Yes        Yes       489
# 4054  5709-LVOEQ  Female              0     Yes        Yes       937
# 5433  7644-OMVMY    Male              0     Yes        Yes      3332
#
#       contract paperlessbilling              paymentmethod  monthlycharges  \
# 945   Two year               No    Credit card (automatic)           56.05
# 1731  Two year               No               Mailed check           20.00
# 1906  Two year              Yes  Bank transfer (automatic)           61.90
# 2025  One year              Yes               Mailed check           19.70
# 2176  Two year               No               Mailed check           20.25
# 2250  Two year               No               Mailed check           25.35
# 2855  Two year               No               Mailed check           73.35
# 3052  Two year               No               Mailed check           25.75
# 3118  Two year              Yes  Bank transfer (automatic)           52.55
# 4054  Two year               No               Mailed check           80.85
# 5433  Two year               No               Mailed check           19.85
#
#       ...  phoneservice     multiplelines  internetservice  id_left2  \
# 945   ...            No  No phone service              DSL      1341
# 1731  ...           Yes                No               No      4381
# 1906  ...           Yes               Yes              DSL      6755
# 2025  ...           Yes                No               No      5219
# 2176  ...           Yes                No               No       754
# 2250  ...           Yes               Yes               No      3827
# 2855  ...           Yes               Yes              DSL      6671
# 3052  ...           Yes               Yes               No      1083
# 3118  ...            No  No phone service              DSL       489
# 4054  ...           Yes                No              DSL       937
# 5433  ...           Yes                No               No      3332
#
#               streamingtv      streamingmovies       onlinesecurity  \
# 945                   Yes                   No                  Yes
# 1731  No internet service  No internet service  No internet service
# 1906                   No                   No                  Yes
# 2025  No internet service  No internet service  No internet service
# 2176  No internet service  No internet service  No internet service
# 2250  No internet service  No internet service  No internet service
# 2855                  Yes                   No                   No
# 3052  No internet service  No internet service  No internet service
# 3118                  Yes                   No                  Yes
# 4054                  Yes                  Yes                  Yes
# 5433  No internet service  No internet service  No internet service
#
#              onlinebackup     deviceprotection          techsupport
# 945                   Yes                  Yes                  Yes
# 1731  No internet service  No internet service  No internet service
# 1906                  Yes                   No                  Yes
# 2025  No internet service  No internet service  No internet service
# 2176  No internet service  No internet service  No internet service
# 2250  No internet service  No internet service  No internet service
# 2855                  Yes                  Yes                  Yes
# 3052  No internet service  No internet service  No internet service
# 3118                   No                  Yes                  Yes
# 4054                  Yes                  Yes                   No
# 5433  No internet service  No internet service  No internet service
#
# [11 rows x 24 columns]

# %%
telco.dropna(how='any', inplace=True)

# %%
print(telco['tenure'].max())
# Out:
# 72

# %%
labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]
telco['tenure_group'] = pd.cut(telco.tenure, range(1, 80, 12), right=False, labels=labels)

# %%
print(labels)
# Out:
# ['1 - 12', '13 - 24', '25 - 36', '37 - 48', '49 - 60', '61 - 72']

# %%
telco['tenure_group'].value_counts()
# Out:
# tenure_group
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: count, dtype: int64

# %%
# Remove columns we dont need for the model
telco.drop(columns=['customerid', 'tenure'], axis=1, inplace=True)

# %%
telco.head()
# Out:
#    gender  seniorcitizen partner dependents  id_left1        contract  \
# 0  Female              0     Yes        Yes      2308        One year
# 1    Male              0      No         No      3489  Month-to-month
# 2    Male              0      No         No      3846  Month-to-month
# 3    Male              1     Yes         No      5932  Month-to-month
# 4  Female              1     Yes         No      5570  Month-to-month
#
#   paperlessbilling     paymentmethod  monthlycharges  totalcharges  ...  \
# 0              Yes      Mailed check            65.6        593.30  ...
# 1               No      Mailed check            59.9        542.40  ...
# 2              Yes  Electronic check            73.9        280.85  ...
# 3              Yes  Electronic check            98.0       1237.85  ...
# 4              Yes      Mailed check            83.9        267.40  ...
#
#   multiplelines  internetservice id_left2 streamingtv streamingmovies  \
# 0            No              DSL     2308         Yes              No
# 1           Yes              DSL     3489          No             Yes
# 2            No      Fiber optic     3846          No              No
# 3            No      Fiber optic     5932         Yes             Yes
# 4            No      Fiber optic     5570         Yes              No
#
#    onlinesecurity onlinebackup deviceprotection techsupport tenure_group
# 0              No          Yes               No         Yes       1 - 12
# 1              No           No               No          No       1 - 12
# 2              No           No              Yes          No       1 - 12
# 3              No          Yes              Yes          No      13 - 24
# 4              No           No               No         Yes       1 - 12
#
# [5 rows x 23 columns]

# %%
import seaborn as sns
for i, predictor in enumerate(telco.drop(columns=['churn', 'totalcharges', 'monthlycharges'])):
    plt.figure(i)
    sns.countplot(data=telco, x=predictor, hue='churn')
# Out:
# /home/shvmpz/PycharmProjects/DATA-ENGINEERING/machine learning spark/venv/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /home/shvmpz/PycharmProjects/DATA-ENGINEERING/machine learning spark/venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Conver the churn to binary with 1 as yes and 0 as no
import numpy as np
telco['churn'] = np.where(telco.churn == 'Yes', 1, 0)

# %%
telco.head()
# Out:
#    gender  seniorcitizen partner dependents  id_left1        contract  \
# 0  Female              0     Yes        Yes      2308        One year
# 1    Male              0      No         No      3489  Month-to-month
# 2    Male              0      No         No      3846  Month-to-month
# 3    Male              1     Yes         No      5932  Month-to-month
# 4  Female              1     Yes         No      5570  Month-to-month
#
#   paperlessbilling     paymentmethod  monthlycharges  totalcharges  ...  \
# 0              Yes      Mailed check            65.6        593.30  ...
# 1               No      Mailed check            59.9        542.40  ...
# 2              Yes  Electronic check            73.9        280.85  ...
# 3              Yes  Electronic check            98.0       1237.85  ...
# 4              Yes      Mailed check            83.9        267.40  ...
#
#    multiplelines  internetservice id_left2 streamingtv streamingmovies  \
# 0             No              DSL     2308         Yes              No
# 1            Yes              DSL     3489          No             Yes
# 2             No      Fiber optic     3846          No              No
# 3             No      Fiber optic     5932         Yes             Yes
# 4             No      Fiber optic     5570         Yes              No
#
#    onlinesecurity onlinebackup deviceprotection techsupport tenure_group
# 0              No          Yes               No         Yes       1 - 12
# 1              No           No               No          No       1 - 12
# 2              No           No              Yes          No       1 - 12
# 3              No          Yes              Yes          No      13 - 24
# 4              No           No               No         Yes       1 - 12
#
# [5 rows x 23 columns]

# %%
# convert categorical data to using dummy library
telco_dummies = pd.get_dummies(telco)
telco_dummies.head()
# Out:
#    seniorcitizen  id_left1  monthlycharges  totalcharges  churn  id_right1  \
# 0              0      2308            65.6        593.30      0       2308
# 1              0      3489            59.9        542.40      0       3489
# 2              0      3846            73.9        280.85      1       3846
# 3              1      5932            98.0       1237.85      1       5932
# 4              1      5570            83.9        267.40      1       5570
#
#    id_left2  gender_Female  gender_Male  partner_No  ...  \
# 0      2308           True        False       False  ...
# 1      3489          False         True        True  ...
# 2      3846          False         True        True  ...
# 3      5932          False         True       False  ...
# 4      5570           True        False       False  ...
#
#    deviceprotection_Yes  techsupport_No  techsupport_No internet service  \
# 0                 False           False                            False
# 1                 False            True                            False
# 2                  True            True                            False
# 3                  True            True                            False
# 4                 False           False                            False
#
#    techsupport_Yes  tenure_group_1 - 12  tenure_group_13 - 24  \
# 0             True                 True                 False
# 1            False                 True                 False
# 2            False                 True                 False
# 3            False                False                  True
# 4             True                 True                 False
#
#    tenure_group_25 - 36  tenure_group_37 - 48  tenure_group_49 - 60  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    tenure_group_61 - 72
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 54 columns]

# %%
# motnly charges and total relationship
sns.lmplot(data=telco, x='monthlycharges', y='totalcharges', fit_reg=False)

# %%
Mth = sns.kdeplot(telco_dummies.monthlycharges[(telco_dummies["churn"] == 0) ],
                color="Red", fill = True)
Mth = sns.kdeplot(telco_dummies.monthlycharges[(telco_dummies["churn"] == 1) ],
                ax =Mth, color="Blue", fill= True)
Mth.legend(["No Churn","Churn"],loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('Monthly Charges')
Mth.set_title('Monthly charges by churn')
# Out:
# Text(0.5, 1.0, 'Monthly charges by churn')

# %%
Tot = sns.kdeplot(telco_dummies.totalcharges[(telco_dummies["churn"] == 0) ],
                color="Red", fill = True)
Tot = sns.kdeplot(telco_dummies.totalcharges[(telco_dummies["churn"] == 1) ],
                ax =Tot, color="Blue", fill= True)
Tot.legend(["No Churn","Churn"],loc='upper right')
Tot.set_ylabel('Density')
Tot.set_xlabel('Total Charges')
Tot.set_title('Total charges by churn')
# Out:
# Text(0.5, 1.0, 'Total charges by churn')

# %%
plt.figure(figsize=(20,8))
telco_dummies.corr()['churn'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %%
new_df1_target0=telco.loc[telco["churn"]==0]
new_df1_target1=telco.loc[telco["churn"]==1]

# %%
def uniplot(df,col,title,hue =None):

    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30

    temp = pd.Series(data = hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())
    fig.set_size_inches(width , 8)
    plt.xticks(rotation=45)
    # plt.yscale('log')  # Commented out to set y-axis scale to linear
    plt.title(title)
    ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue,palette='bright')

    plt.show()

# %%
uniplot(new_df1_target1,col='partner',title='Distribution of Gender for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target0,col='partner',title='Distribution of Gender for Non Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='paymentmethod',title='Distribution of PaymentMethod for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='contract',title='Distribution of Contract for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='techsupport',title='Distribution of TechSupport for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='seniorcitizen',title='Distribution of SeniorCitizen for Churned Customers',hue='gender')

# %%
telco_dummies.to_csv('tel_churn.csv')
